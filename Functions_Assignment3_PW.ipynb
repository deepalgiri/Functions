# %% [markdown]
# ## **Theory Questions:**

# %% [markdown]
# **Q1. What is the difference between a function and a method in Python?**
#
#
# * #### **Function**
#
# * Definition: A function is a standalone block of code that performs a specific task. It is defined using the def keyword.
#
# * Association: Functions are not tied to any object or class.
#
# * Invocation: Called directly by their name, e.g., function_name().
#
# * Access to Data: Functions operate solely on the data provided to them through parameters.
#
#        Example:
#        def greet(name):
#           return f"Hello, {name}!"
#
#       print(greet("Alice"))  # Output: Hello, Alice!
#
# * #### **Method**
#
#
#
# * Definition: A method is a function that is defined within a class and is associated with the objects of that class.
#
# * Association: Methods are tied to the class or its instances.
#
# * Invocation: Called on an object using dot notation, e.g., object.method_name().
#
# * Access to Data: Methods can access and modify the object's attributes.​
#
#          Example:
#          class Greeter:
#              def __init__(self, name):
#                  self.name = name
#
#              def greet(self):
#                  return f"Hello, {self.name}!"
#
#          greeter = Greeter("Bob")
#          print(greeter.greet())  # Output: Hello, Bob!

# %% [markdown]
# **Q2. Explain the concept of function arguments and parameters in Python.**
#
#
# * **Parameters:** These are variables listed inside the parentheses in a function definition. They act as placeholders for the values that the function will receive when called.​
#            Example:
#                 def greet(name):  # 'name' is a parameter
#                     print(f"Hello, {name}!")
#
#
# * Arguments: These are the actual values passed to the function when it is invoked. They are assigned to the corresponding parameters in the function definition.​
#
#            Example:
#                 greet("Alice")    # "Alice" is an argument

# %% [markdown]
# **3. What are the different ways to define and call a function in Python?**
#
#
# * **1. Standard Function Definition**
#
# * Use the def keyword to define a function:
#
#       def greet(name):
#           return f"Hello, {name}!"
# * Call:
#       say_hello("Alice")
#
#
# * **2. Lambda (Anonymous) Functions**
# * For simple, single-expression functions:
#          square = lambda x: x * x
#          print(square(5))  # Output: 25
# * Call:
#         square(5)  # → 25
#
#
# * **3. Nested Functions**
# * Define functions within other functions:
#         def outer():
#             def inner():
#                 print("Inner function")
#             inner()
# * Call:
#        outer()
#
#
# * **4. Functions with Default Parameters**
#
# * Provide default values for parameters:
#
#        def greet(name="Guest"):
#            return f"Hello, {name}!"
# * Call:
#        greet("Bob")              # Uses default greeting
#        greet("Carol", "Hello")   # Overrides default
#
#
#
# * **5. Variable-Length Arguments**
#
#
# * Handle arbitrary numbers of arguments:
#
#         def add(*args):
#             return sum(args)
#
#   * Call:
#        add_numbers(1, 2, 3, 4)  # → 10
#        show_info(name="Alice", age=30)
#
#
# * **6. Function as an Argument (Higher-Order Function)**
#
#
# * You can pass functions as arguments to other functions.
# * Define:
#          def shout(text):
#              return text.upper()
#
#          def whisper(text):
#              return text.lower()
#
#          def speak(style_func, message):
#              print(style_func(message))
#
# * Call:
#         speak(shout, "hello")  # → HELLO
#         speak(whisper, "HELLO")  # → hello
#
#
# * **7. Recursive Function**
#
# * A function that calls itself.
# * Define:
#         def factorial(n):
#             if n == 1:
#                 return 1
#             return n * factorial(n - 1)
#
#
# * Call:
#        factorial(5)  # → 120

# %% [markdown]
# **Q4. What is the purpose of the `return` statement in a Python function?**
# * The return statement serves to exit a function and optionally pass back a value to the caller. This mechanism is fundamental for functions that compute and provide results for further use in a program.
#
#
# * **Purpose of return**
#
# * 1.Send data back to the caller:
#
#       def add(a, b):
#           return a + b
#
#       result = add(2, 3)  # result is now 5
#
# * 2.End function execution:
# * As soon as return is hit, the function stops running.
#        def test():
#            print("Before return")
#            return
#            print("After return")  # This line never runs
# * 3.Return multiple values (as a tuple):
#           def get_stats():
#               return 5, 10, 15
#
#           a, b, c = get_stats()  # a=5, b=10, c=15
#
# * 4.Return nothing (implicitly returns None):
#        def do_nothing():
#            pass
#
#        print(do_nothing())  # Outputs: None

# %% [markdown]
# **Q5. What are iterators in Python and how do they differ from iterables?**
#
#
# * **Iterables**
# * An iterable is any Python object that can be looped over (i.e., you can use it in a for loop).
# It implements the __iter__() method and returns an iterator.
#
# * Examples of Iterables: Lists,
# Tuples,
# Strings,
# Sets,
# Dictionaries
#          my_list = [1, 2, 3]
#          for item in my_list:
#              print(item)
#
# * **Iterator**
# * An iterator is the actual object that does the iteration.
# It is returned by calling iter() on an iterable and knows how to fetch the next item using the __next__() method.
#       my_iter = iter([1, 2, 3])
#       print(next(my_iter))  # 1
#       print(next(my_iter))  # 2
#       print(next(my_iter))  # 3
#      # next(my_iter) → raises StopIteration
#
# * ### **Key Differences**
#
# * **Feature..........................................	Iterable...............................................	Iterator**
# * Usage.....................................	Can be looped over (e.g. for).................................	Used to fetch items one by one
# * Has __iter__()............................................. Yes......................................................	Yes (returns itself)
# * Has __next__()...........................................	No (usually)............................................	Yes
# * Examples...................................	List, String, Dict........................................	Object from iter() or a generator

# %% [markdown]
# **Q6. Explain the concept of generators in Python and how they are defined.**
#
#
# *  What is a Generator?
# * A generator is a function that uses the yield statement instead of return. When called, it doesn’t execute the function body immediately. Instead, it returns a generator object, which can be iterated over (like with a for loop or next()).
# * **How to Define a Generator**
# * 1.Using a Function with yield:
#
#       def count_up_to(n):
#           i = 1
#           while i <= n:
#               yield i
#               i += 1
#
# * When you call count_up_to(5), it doesn't run the function—it returns a generator object.
#        gen = count_up_to(5)
#        print(next(gen))  # 1
#        print(next(gen))  # 2
#      # ... keeps going until it reaches 5
# * 2.Using Generator Expressions (like list comprehensions)
#
#        squares = (x * x for x in range(5))  # Note the () instead of []
#        print(next(squares))  # 0

# %% [markdown]
# **Q7. What are the advantages of using generators over regular functions?**
#
#
# * Generators in Python offer several advantages over regular functions, especially when dealing with large data sets or streaming data. Here are the key benefits:
#
#
# * **1.Memory Efficiency**
#
# *   Generators don’t store all values in memory—they yield one value at a time.
#
# * Perfect for huge data sets or infinite sequences.
#
# * Example:
#
#   # This doesn't store all numbers in memory
#        def count_up_to(n):
#            i = 1
#            while i <= n:
#                yield i
#                i += 1
#
#
#
#
# * Compare that to returning a giant list:
#            def count_up_to_list(n):
#                return [i for i in range(1, n + 1)]
#
# * **2. Lazy Evaluation**
#
#
# * Values are produced on demand, not all at once.
#
# * This makes them ideal for pipelines, processing data as it's needed.
#
# * **3. Infinite Sequences :**
#
# * Generators can keep producing values forever, because they don’t pre-compute everything.
#
#       def infinite_count(start=0):
#       while True:
#       yield start
#       start += 1
# * Try doing that with a list — your computer will run out of memory!
#
# * **4. Easily Composable**
# * Generators can be chained together using generator expressions or comprehensions.
#
# * You can build complex processing pipelines that are both readable and memory-efficient.
#
#       squares = (x*x for x in range(1000000))  # Doesn’t create a million items in memory
#
#
# * **5. 3. State Retention Without Global Variables**
# * A generator remembers where it left off between yield statements, which is simpler than managing state manually in a regular function.
#      def countdown(n):
#          while n > 0:
#              yield n
#              n -= 1

# %% [markdown]
# **Q8. What is a lambda function in Python and when is it typically used?**
#
#
# * A lambda function in Python is a small, anonymous function defined using the lambda keyword. It’s typically used for short, throwaway functions where defining a full def-based function would be overkill.
#
#
# * Syntax:
#         lambda arguments: expression
#
#  Example:
#
#        square = lambda x: x * x
#        print(square(5))  # Output: 25
#
#
# * When Is a Lambda Function Typically Used?
# * They're most useful when you need a short function for a short time, especially in places where defining a full def function would be overkill.
# * Common Use Cases :
# * Used with map() (apply function to each item in a list):
#       nums = [1, 2, 3, 4]
#       squares = list(map(lambda x: x ** 2, nums))
#       print(squares) # [1, 4, 9, 16]
# * Used with filter() (filter items based on a condition):
#       evens = list(filter(lambda x: x % 2 == 0, nums))
#       print(evens) # [2, 4]
# * Used with sorted() (custom sorting):
#       names = ["Alice", "Bob", "Charlie"]
#       sorted_names = sorted(names, key=lambda name: len(name))
#       print(sorted_names) # ['Bob', 'Alice', 'Charlie']
# * Used with GUI, event handling, or frameworks (quick callbacks):
#       button.on_click(lambda: print("Clicked!"))

# %% [markdown]
# **Q9. Explain the purpose and usage of the `map()` function in Python.**
#
#
# * The map() function in Python is used to apply a given function to all items in an iterable (like a list, tuple, etc.) and return a new iterable (a map object) with the results. It’s a cleaner and often more efficient alternative to using a for loop when you want to transform data.
# * Syntax:
#        map(function, iterable)
#
#
# * function: A function that takes one argument (or more, if multiple iterables are provided).
#
# * iterable: One or more iterables (e.g., lists, tuples) to process.
#
# * How map() Works :
# * Step 1: It takes a function and an iterable.
# * Step 2: It applies the function to each element of the iterable.
# * Step 3: It returns an iterator that can be looped over to get the results.
# * Examples of Using map()
# * Using map() with a Lambda Function : You can apply a simple transformation like squaring each number in a list using lambda:
#        nums = [1, 2, 3, 4]
#        squared = map(lambda x: x ** 2, nums)
#     # Convert map object to list to see the result
#
#       print(list(squared)) # Output: [1, 4, 9, 16]
# * Using map() with a Regular Function : You can also use a regular function instead of a lambda.
#         def double(x):
#         return x * 2
#         nums = [1, 2, 3, 4]
#         doubled = map(double, nums)
#         print(list(doubled)) # Output: [2, 4, 6, 8]
# * Using map() with Multiple Iterables : If you have multiple iterables, map() can take more than one iterable and apply the function to the items from all of them simultaneously (pairing elements together):
#        nums1 = [1, 2, 3]
#        nums2 = [4, 5, 6]
#     # Adding corresponding elements
#
#      result = map(lambda x, y: x + y, nums1, nums2)
#      print(list(result)) # Output: [5, 7, 9]
# * Key Benefits of Using map() :
# * Compact and Concise: Helps in applying functions to each element in an iterable without needing a loop.
# * Cleaner Code: Reduces the need for boilerplate code, making your transformations more readable.
# * Efficient: Since it returns an iterator, it computes values lazily, making it memory-efficient for large data sets.

# %% [markdown]
# **Q10. What is the difference between `map()`, `reduce()`, and `filter()` functions in Python?**
#
#
# * 1.map() Function : The map() function applies a given function to each item in an iterable (or multiple iterables) and returns a new iterable (typically an iterator) of the results.
#
# * Purpose: Applies a function to each item in an iterable and returns a map object (which is an iterator).
#
# * Use case: When you want to transform every element in a collection.
#
#        Example:
#        nums = [1, 2, 3, 4]
#        squared = map(lambda x: x**2, nums)
#        print(list(squared))  # Output: [1, 4, 9, 16]
#
# * 2.reduce() Function : The reduce() function is part of the functools module and works by reducing a sequence of elements to a single value by applying a binary function cumulatively to the items.
# * Purpose: Applies a function cumulatively to the items of an iterable, reducing it to a single value.
#
# * Use case: When you want to aggregate or combine all elements into one (e.g., sum, product).
#
# * Note: You have to import reduce from functools.
#        Example:
#        from functools import reduce
#        nums = [1, 2, 3, 4]
#        product = reduce(lambda x, y: x * y, nums)
#        print(product)  # Output: 24
# * 3.filter() Function : The filter() function filters an iterable by applying a function that returns True or False to each item, keeping only the items that evaluate to True.
# * Purpose: Filters elements from an iterable based on a function that returns True or False.
#
# * Use case: When you want to select a subset of elements that meet a condition.
#        Example:
#               nums = [1, 2, 3, 4]
#               even = filter(lambda x: x % 2 == 0, nums)
#               print(list(even))  # Output: [2, 4]

# %% [markdown]
# **Q11.** **Using pen & Paper write the internal mechanism for sum operation using  reduce function on this given**
# **list:[47,11,42,13];**
# ![function.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## **Practical Questions:**

# %%
# 1. Write a Python function that takes a list of numbers as input and returns the sum of all even numbers in the list.

def sum_even_numbers(numbers):
    return sum(num for num in numbers if num % 2 == 0)

# Example usage:
my_list = [1, 2, 3, 4, 5, 6]
result = sum_even_numbers(my_list)
print("Sum of even numbers:", result)
# Out:
# Sum of even numbers: 12

# %%
# Q2. Create a Python function that accepts a string and returns the reverse of that string.
def reverse_string(s):
    return s[::-1]

# Example usage:
input_str = "ayiR, iraY!"
reversed_str = reverse_string(input_str)
print("Reversed string:", reversed_str)
# Out:
# Reversed string: !Yari ,Riya

# %%
# 3. Implement a Python function that takes a list of integers and returns a new list containing the squares of each number.
def square_list(numbers):
    return [num ** 2 for num in numbers]

# Example usage:
input_list = [1, 2, 3, 4, 5]
output_list = square_list(input_list)
print("Squared list:", output_list)
# Out:
# Squared list: [1, 4, 9, 16, 25]

# %%
#Q 4. Write a Python function that checks if a given number is prime or not from 1 to 200.
def is_prime(n):
    if n <= 1:
        return False
    for i in range(2, int(n**0.5) + 1):
        if n % i == 0:
            return False
    return True

# Get user input
num = int(input("Enter a number between 1 and 200: "))

if 1 <= num <= 200:
    if is_prime(num):
        print(f"{num} is a prime number.")
    else:
        print(f"{num} is not a prime number.")
else:
    print("Number out of range. Please enter a number between 1 and 200.")
# Out:
# Enter a number between 1 and 200: 55
# 55 is not a prime number.

# %%
#Q 5. Create an iterator class in Python that generates the Fibonacci sequence up to a specified number of terms.
class FibonacciIterator:
    def __init__(self, max_terms):
        self.max_terms = max_terms
        self.count = 0
        self.a = 0
        self.b = 1

    def __iter__(self):
        return self

    def __next__(self):
        if self.count >= self.max_terms:
            raise StopIteration
        if self.count == 0:
            self.count += 1
            return 0
        elif self.count == 1:
            self.count += 1
            return 1
        else:
            self.count += 1
            self.a, self.b = self.b, self.a + self.b
            return self.a
#OR
class FibonacciIterator:
    def __init__(self, max_terms):
        self.max_terms = max_terms
        self.count = 0
        self.a = 0
        self.b = 1

    def __iter__(self):
        return self

    def __next__(self):
        if self.count >= self.max_terms:
            raise StopIteration
        if self.count == 0:
            self.count += 1
            return 0
        elif self.count == 1:
            self.count += 1
            return 1
        else:
            self.count += 1
            self.a, self.b = self.b, self.a + self.b
            return self.a

# ✅ User Input
try:
    n = int(input("Enter the number of Fibonacci terms to generate: "))
    if n <= 0:
        print("Please enter a positive integer.")
    else:
        print("Fibonacci Sequence:")
        for num in FibonacciIterator(n):
            print(num, end=" ")
except ValueError:
    print("Invalid input. Please enter an integer.")
# Out:
# Enter the number of Fibonacci terms to generate: 7
# Fibonacci Sequence:
# 0 1 1 1 2 3 5

# %%
#Q6. Write a generator function in Python that yields the powers of 2 up to a given exponent.
def powers_of_two(exponent):
    for i in range(exponent + 1):
        yield 2 ** i
n = int(input("Enter the exponent value: "))

print("Powers of 2 up to 2^", n)
for power in powers_of_two(n):
    print(power, end=" ")
# Out:
# Enter the exponent value: 11
# Powers of 2 up to 2^ 11
# 1 2 4 8 16 32 64 128 256 512 1024 2048

# %%
#Q 7. Implement a generator function that reads a file line by line and yields each line as a string.
def read_file_line_by_line(file_name):
    with open(file_name, 'r') as file:
        for line in file:
            yield line.strip()  # .strip() removes the newline at the end of each line
file_name = input("Enter the file name to read: ")

try:
    # Using the generator function
    for line in read_file_line_by_line(file_name):
        print(line)
except FileNotFoundError:
    print(f"The file {file_name} does not exist.")
# Out:
# Enter the file name to read: 5
# The file 5 does not exist.

# %%
#Q8. Use a lambda function in Python to sort a list of tuples based on the second element of each tuple.
# List of tuples
data = [(1, 5), (3, 1), (2, 4), (4, 2)]

# Sort using lambda function based on the second element of each tuple
sorted_data = sorted(data, key=lambda x: x[1])

# Output the sorted list
print(sorted_data)
# Out:
# [(3, 1), (4, 2), (2, 4), (1, 5)]

# %%
#Q 9. Write a Python program that uses `map()` to convert a list of temperatures from Celsius to Fahrenheit.
# Function to convert Celsius to Fahrenheit
def celsius_to_fahrenheit(celsius):
    return (celsius * 9/5) + 32

# List of temperatures in Celsius
celsius_temperatures = [0, 10, 20, 30, 40, 50]

# Use map() to apply the conversion function to each element in the list
fahrenheit_temperatures = list(map(celsius_to_fahrenheit, celsius_temperatures))

# Print the result
print("Celsius temperatures:", celsius_temperatures)
print("Converted to Fahrenheit:", fahrenheit_temperatures)
# Out:
# Celsius temperatures: [0, 10, 20, 30, 40, 50]
# Converted to Fahrenheit: [32.0, 50.0, 68.0, 86.0, 104.0, 122.0]

# %%
#Q 10. Create a Python program that uses `filter()` to remove all the vowels from a given string.
# Function to check if a character is not a vowel
def is_not_vowel(char):
    return char.lower() not in 'aeiou'

# Input string
input_string = input("Enter a string: ")

# Use filter() to remove vowels
filtered_string = ''.join(filter(is_not_vowel, input_string))

# Output the result
print("String after removing vowels:", filtered_string)
# Out:
# Enter a string: dishu
# String after removing vowels: dsh

# %%
"""Q 11) Imagine an accounting routine used in a book shop. It works on a list with sublists, which look like this:
 Write a Python program, which returns a list with 2-tuples. Each tuple consists of the order number and the
product of the price per item and the quantity. The product should be increased by 10,- € if the value of the
order is smaller than 100,00 €.
 Write a Python program using lambda and map"""
 # Data: Each sublist contains Order number, Book title, Author, Quantity, Price per item
orders = [
    [34587, 'Learning Python', 'Mark Lutz', 4, 40.95],
    [98762, 'Programming Python', 'Mark Lutz', 5, 56.80],
    [77226, 'Head First Python', 'Paul Barry', 3, 32.95],
    [88112, 'Einfuhrung in Python3', 'Bernd Klien', 3, 24.99]
]

# Function to compute the total and apply the +10€ rule if total < 100€
def calculate_order_value(order):
    order_number = order[0]
    quantity = order[3]
    price_per_item = order[4]

    # Calculate the total order value
    total_value = quantity * price_per_item

    # If total is less than 100€, add 10€
    if total_value < 100:
        total_value += 10

    # Return a tuple of (order_number, total_value)
    return (order_number, total_value)

# Apply the function using map() and lambda
result = list(map(lambda order: (order[0], (order[3] * order[4] + 10) if (order[3] * order[4]) < 100 else order[3] * order[4]), orders))

# Output the result
print(result)
# Out:
# [(34587, 163.8), (98762, 284.0), (77226, 108.85000000000001), (88112, 84.97)]
